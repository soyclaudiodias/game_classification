# %% [markdown]
# # 📌 Treinamento do Modelo – Explicação Geral
# Este notebook treina um classificador de gêneros de jogos usando TF‑IDF e SVM.

# %% [markdown]
# ## 🔹 Carregando o Dataset
# Carregamos o CSV com descrições e gêneros dos jogos.

# %%
import pandas as pd
import ast

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
import joblib

# Carrega o CSV gerado no notebook de coleta
df = pd.read_csv("../data/games_extended.csv")
print("Shape carregado do CSV:", df.shape)
df.head()
# Out:
# Shape carregado do CSV: (400, 3)
#                                name  \
# 0                Grand Theft Auto V
# 1          The Witcher 3: Wild Hunt
# 2                          Portal 2
# 3  Counter-Strike: Global Offensive
# 4                Tomb Raider (2013)
#
#                                          description                 genres
# 0  Rockstar Games went bigger, since their previo...           ['Strategy']
# 1  The third game in a series, it holds nothing b...      ['Action', 'RPG']
# 2  Portal 2 is a first-person puzzle game develop...  ['Shooter', 'Puzzle']
# 3  Counter-Strike is a multiplayer phenomenon in ...            ['Shooter']
# 4  A cinematic revival of the series in its actio...             ['Action']

# %% [markdown]
# ## 🔹 Separação Treino/Teste
# Dividimos os dados em treino e teste para avaliar o modelo.

# %% [markdown]
# ## 🔹 Preparação: Separação Treino/Teste
# O dataset é dividido em treino e teste para validar a performance do modelo.

# %% [markdown]
# ## 🔹 Vetorização TF‑IDF
# Transformamos o texto das descrições em vetores numéricos.

# %%
# Garante que a descrição não é nula
df["description"] = df["description"].fillna("")

def first_genre(genres_obj):
    """
    Converte a coluna 'genres' (lista ou string de lista) e retorna apenas
    o primeiro gênero, para simplificar o problema de classificação.
    """
    # Se já veio como lista
    if isinstance(genres_obj, list):
        return genres_obj[0] if len(genres_obj) > 0 else "Unknown"
    # Se veio como string representando lista
    try:
        genres_list = ast.literal_eval(genres_obj)
        if isinstance(genres_list, list) and len(genres_list) > 0:
            return genres_list[0]
    except Exception:
        pass
    return "Unknown"

df["genre"] = df["genres"].apply(first_genre)

# Remove descrições extremamente curtas
df = df[df["description"].str.len() > 10]

print("Shape depois do tratamento:", df.shape)
print("Distribuição de gêneros:")
print(df["genre"].value_counts())
df[["name", "genre"]].head()
# Out:
# Shape depois do tratamento: (400, 4)
# Distribuição de gêneros:
# genre
# Action        308
# Adventure      28
# Strategy       20
# RPG            18
# Shooter        11
# Simulation      5
# Racing          3
# Indie           3
# Sports          1
# Platformer      1
# Casual          1
# Arcade          1
# Name: count, dtype: int64
#                                name     genre
# 0                Grand Theft Auto V  Strategy
# 1          The Witcher 3: Wild Hunt    Action
# 2                          Portal 2   Shooter
# 3  Counter-Strike: Global Offensive   Shooter
# 4                Tomb Raider (2013)    Action

# %% [markdown]
# ## 🔹 Avaliação do Modelo
# Medimos a acurácia no conjunto de teste.

# %%
# Avaliação simples de acurácia no conjunto de teste
X_test_vec = vectorizer.transform(X_test)
accuracy = clf.score(X_test_vec, y_test)
print("Acurácia no conjunto de teste:", accuracy)
# Out:
# Acurácia no conjunto de teste: 0.7375

# %% [markdown]
# ## 🔹 Salvando o Modelo Treinado
# O modelo e o vetorizador serão salvos na pasta `../model/`.

# %%
import pathlib, joblib

model_dir = pathlib.Path("../model")
model_dir.mkdir(exist_ok=True)

classifier_path = model_dir / "classifier.pkl"
vectorizer_path = model_dir / "vectorizer.pkl"

joblib.dump(clf, classifier_path)
joblib.dump(vectorizer, vectorizer_path)

print("Modelo salvo em:", classifier_path)
print("Vetorizador salvo em:", vectorizer_path)
# Out:
# Modelo salvo em: ..\model\classifier.pkl
# Vetorizador salvo em: ..\model\vectorizer.pkl
